# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank             Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1     Michael Jordan   27  CHI   77.0    891.0      960
# 1             1    2      Magic Johnson   31  LAL   10.0    497.0      960
# 2             2    3     David Robinson   25  SAS    6.0    476.0      960
# 3             3    4    Charles Barkley   27  PHI    2.0    222.0      960
# 4             4    5        Karl Malone   27  UTA    0.0    142.0      960
# ..          ...  ...                ...  ...  ...    ...      ...      ...
# 469          10   11  Russell Westbrook   32  WAS    0.0      5.0     1010
# 470          11   12        Ben Simmons   24  PHI    0.0      3.0     1010
# 471          12  13T       James Harden   31  TOT    0.0      1.0     1010
# 472          13  13T       LeBron James   36  LAL    0.0      1.0     1010
# 473          14  13T      Kawhi Leonard   29  LAC    0.0      1.0     1010
#
# ...

# %%
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps.head()
# Out:
#             Player  Year  Pts Won  Pts Max  Share
# 0   Michael Jordan  1991    891.0      960  0.928
# 1    Magic Johnson  1991    497.0      960  0.518
# 2   David Robinson  1991    476.0      960  0.496
# 3  Charles Barkley  1991    222.0      960  0.231
# 4      Karl Malone  1991    142.0      960  0.148

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 18039         725  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9
# 18040         726  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4
# 18041         727  538          Trae Young  PG  22  ATL  63  63  33.7  7.7
# 18042         728  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8
# 18043         729  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
del players["Unnamed: 0"]
del players["Rk"]

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...  0.6
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...  0.5
# 2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...  2.1
# 3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...  0.9
# 4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...  1.7
#
#    DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# 0  1.4  2.1   0.3  0.1  0.3  0.5  0.9   3.1  1991
# 1  1.3  1.8   3.1  0.8  0.1  1.6  2.2  14.1  1991
# 2  3.2  5.3   0.4  0.4  0.4  0.6  3.2   4.2  1991
# 3  3.0  3.9  10.5  2.2  0.1  3.6  2.5  26.5  1991
# 4  3.1  4.8   1.8  0.6  0.3  1.6  2.7  14.2  1991
#
# [5 rows x 30 columns]

# %%
players["Player"] = players["Player"].str.replace("*", "", regex=False)

# %%
players.head(20)
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0       Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7   .474  ...  0.6
# 1   Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1   .413  ...  0.5
# 2           Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1   .509  ...  2.1
# 3        Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5   .394  ...  0.9
# 4         Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7   .462  ...  1.7
# 5          Danny Ainge  SG  31  POR  80   0  21.4  4.2   8.9   .472  ...  0.6
# 6          Mark Alarie  PF  27  WSB  42   1  14.0  2.4   5.4   .440  ...  1.0
# 7         Steve Alford  PG  26  DAL  34   0   6.9  1.7   3.4   .504  ...  0.3
# 8        Greg Anderson  PF  26  TOT  68   2  13.6  1.7   4.0   .430  ...  1.4
# 9        Greg Anderson  PF  26  MIL  26   0   9.5  1.0   2.8   .370  ...  1.0
# 10       Greg Anderson  PF  26  NJN   1   0  18.0  4.0   4.0  1.000  ...  4.0
# ...

# %%
players.groupby(["Player", "Year"]).get_group(("Greg Anderson", 1991))
# Out:
#            Player Pos Age   Tm   G GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  TOT  68  2  13.6  1.7  4.0   .430  ...  1.4  3.3
# 9   Greg Anderson  PF  26  MIL  26  0   9.5  1.0  2.8   .370  ...  1.0  1.9
# 10  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  4.0  1.000  ...  4.0  2.0
# 11  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7   .440  ...  1.6  4.1
#
#     TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 8   4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 9   2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 10  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 11  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %%
def single_row(df):
    if df.shape[0]==1:
        return df
    else:
        row = df[df["Tm"] == "TOT"]
        row["Tm"] = df.iloc[-1,:]["Tm"]
        return row
    
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# ...

# %%
players.index = players.index.droplevel()

# %%
players.head()
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# Year                                                               ...
# 1991 164   A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5
# 1992 633   A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7
# 1993 1092  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5
# 1994 1579  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4
# 1995 2067  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4
#
#            DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# Year
# 1991 164   3.8  6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 1992 633   5.6  9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1993 1092  5.2  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 1994 1579  5.8  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 1995 2067  5.8  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
#
# [5 rows x 30 columns]

# %%
players.index = players.index.droplevel()

# %%
players.head()
# Out:
#           Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  DRB  \
# 164   A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5  3.8
# 633   A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7  5.6
# 1092  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5  5.2
# 1579  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4  5.8
# 2067  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4  5.8
#
#       TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 164   6.3  0.9  0.7  0.3  1.2  1.4   9.1  1991
# 633   9.3  1.4  1.1  0.4  1.4  1.7  13.6  1992
# 1092  8.7  1.4  1.1  0.5  1.4  1.8  12.8  1993
# 1579  9.2  1.7  0.9  0.5  1.2  1.7  14.7  1994
# 2067  8.2  1.5  0.7  0.4  1.4  1.8  11.2  1995
#
# [5 rows x 30 columns]

# %%
players[players["Player"]  == "Michael Jordan"]
# Out:
#               Player Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  ORB  \
# 212   Michael Jordan  SG  27  CHI  82  82  37.0  12.1  22.4  .539  ...  1.4
# 683   Michael Jordan  SG  28  CHI  80  80  38.8  11.8  22.7  .519  ...  1.1
# 1140  Michael Jordan  SG  29  CHI  78  78  39.3  12.7  25.7  .495  ...  1.7
# 2118  Michael Jordan  SG  31  CHI  17  17  39.3   9.8  23.8  .411  ...  1.5
# 2616  Michael Jordan  SG  32  CHI  82  82  37.7  11.2  22.6  .495  ...  1.8
# 3202  Michael Jordan  SG  33  CHI  82  82  37.9  11.2  23.1  .486  ...  1.4
# 3782  Michael Jordan  SG  34  CHI  82  82  38.8  10.7  23.1  .465  ...  1.6
# 5956  Michael Jordan  SF  38  WAS  60  53  34.9   9.2  22.1  .416  ...  0.8
# 6464  Michael Jordan  SF  39  WAS  82  67  37.0   8.3  18.6  .445  ...  0.9
#
#       DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 212   4.6  6.0  5.5  2.7  1.0  2.5  2.8  31.5  1991
# 683   5.3  6.4  6.1  2.3  0.9  2.5  2.5  30.1  1992
# ...

# %%
combined = players.merge(mvps, how="outer", on=["Player","Year"])

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     NaN     NaN   NaN
# 1  1.4  1.7  13.6  1992     NaN     NaN   NaN
# 2  1.4  1.8  12.8  1993     NaN     NaN   NaN
# 3  1.2  1.7  14.7  1994     NaN     NaN   NaN
# 4  1.4  1.8  11.2  1995     NaN     NaN   NaN
#
# [5 rows x 33 columns]

# %%
combined[["Pts Won", "Pts Max", "Share"]] = combined[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9
# 1          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4
# 2          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4
# 3          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7
# 4          A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 14087  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.5
# 14088  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.3
# 14089  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.3
# 14090  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.4
# 14091  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.3
#
# ...

# %%
teams = pd.read_csv("teams.csv")

# %%
teams
# Out:
#       Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0              0  56  26  .683     —  111.5  105.7   5.22  1991
# 1              1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2              2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3              3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4              4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ...          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 1028          13  42  30  .583     —  112.4  110.2   2.26  2021
# 1029          14  38  34  .528   4.0  113.3  112.3   1.07  2021
# 1030          15  33  39  .458   9.0  111.1  112.8  -1.58  2021
# 1031          16  31  41  .431  11.0  114.6  114.9  -0.20  2021
# 1032          17  17  55  .236  25.0  108.8  116.7  -7.50  2021
#
#                       Team
# 0          Boston Celtics*
# 1      Philadelphia 76ers*
# 2         New York Knicks*
# 3       Washington Bullets
# 4          New Jersey Nets
# ...                    ...
# ...

# %%
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams["Team"] = teams["Team"].str.replace("*","", regex=False)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_22876/2589434302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams["Team"] = teams["Team"].str.replace("*","", regex=False)

# %%
teams.head(5)
# Out:
#    Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0           0  56  26  .683     —  111.5  105.7   5.22  1991
# 1           1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2           2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3           3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4           4  26  56  .317  30.0  102.9  107.5  -4.53  1991
#
#                  Team
# 0      Boston Celtics
# 1  Philadelphia 76ers
# 2     New York Knicks
# 3  Washington Bullets
# 4     New Jersey Nets

# %%
del teams["Unnamed: 0"]

# %%
nicknames = {}

with open("nicknames.csv") as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbrev, name = line.replace("\n","").split(",")
        nicknames[abbrev] = name

# %%
nicknames
# Out:
# {'ATL': 'Atlanta Hawks',
#  'BRK': 'Brooklyn Nets',
#  'BKN': 'Brooklyn Nets',
#  'BOS': 'Boston Celtics',
#  'CHA': 'Charlotte Bobcats',
#  'CHH': 'Charlotte Hornets',
#  'CHO': 'Charlotte Hornets',
#  'CHI': 'Chicago Bulls',
#  'CLE': 'Cleveland Cavaliers',
#  'DAL': 'Dallas Mavericks',
#  'DEN': 'Denver Nuggets',
#  'DET': 'Detroit Pistons',
#  'GSW': 'Golden State Warriors',
#  'HOU': 'Houston Rockets',
#  'IND': 'Indiana Pacers',
#  'LAC': 'Los Angeles Clippers',
#  'LAL': 'Los Angeles Lakers',
#  'MEM': 'Memphis Grizzlies',
#  'MIA': 'Miami Heat',
#  'MIL': 'Milwaukee Bucks',
#  'MIN': 'Minnesota Timberwolves',
#  'NJN': 'New Jersey Nets',
#  'NOH': 'New Orleans Hornets',
#  'NOP': 'New Orleans Pelicans',
#  'NOK': 'New Orleans/Oklahoma City Hornets',
#  'NYK': 'New York Knicks',
#  'OKC': 'Oklahoma City Thunder',
#  'ORL': 'Orlando Magic',
#  'PHI': 'Philadelphia 76ers',
#  'PHX': 'Phoenix Suns',
#  'PHO': 'Phoenix Suns',
#  'POR': 'Portland Trail Blazers',
# ...

# %%
combined["Team"] = combined["Tm"].map(nicknames)

# %%
combined.head(5)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
#
#     PF   PTS  Year Pts Won Pts Max Share                Team
# 0  1.4   9.1  1991     0.0     0.0   0.0  Los Angeles Lakers
# 1  1.7  13.6  1992     0.0     0.0   0.0  Los Angeles Lakers
# 2  1.8  12.8  1993     0.0     0.0   0.0  Los Angeles Lakers
# 3  1.7  14.7  1994     0.0     0.0   0.0        Phoenix Suns
# 4  1.8  11.2  1995     0.0     0.0   0.0        Phoenix Suns
#
# [5 rows x 34 columns]

# %%
stats = combined.merge(teams, how="outer", on=["Team", "Year"])

# %%
stats
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...
# 1         Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  .477  ...
# 2      Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  .455  ...
# 3       Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9  .340  ...
# 4        James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  .492  ...
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 14087   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  .484  ...
# 14088     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  .286  ...
# 14089  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1  .470  ...
# 14090      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  .459  ...
# 14091      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  .455  ...
#
#       Pts Max Share                Team   W   L  W/L%   GB   PS/G   PA/G  \
# ...

# %%
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7
# 1          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1
# 2          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1
# 3          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9
# 4          A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 14087  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.4
# 14088  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.2
# 14089  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.2
# 14090  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.2
# 14091  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.2
#
# ...

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats["GB"].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0', '33.0',
#        '31.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
stats["GB"] = stats["GB"].str.replace("—", "0")

# %%
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
stats.to_csv("player_mvp_stats.csv")

# %%
highest_scoring = stats[stats["G"] > 70].sort_values("PTS", ascending=False).head(10)

# %%
highest_scoring.plot.bar("Player", "PTS")
# Out:
# <AxesSubplot:xlabel='Player'>

# %%
high_scoring = stats.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
high_scoring.plot.bar("Year", "PTS")
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
stats.corr()["Share"]
# Out:
# Age        0.018596
# G          0.089282
# GS         0.167476
# MP         0.162175
# FG         0.276365
# FGA        0.249254
# FG%        0.065789
# 3P         0.096225
# 3PA        0.096460
# 3P%        0.013611
# 2P         0.275976
# 2PA        0.251885
# 2P%        0.063240
# eFG%       0.059335
# FT         0.316392
# FTA        0.321457
# FT%        0.037875
# ORB        0.101375
# DRB        0.213241
# TRB        0.186209
# AST        0.200253
# STL        0.175041
# BLK        0.154713
# TOV        0.233015
# PF         0.071045
# PTS        0.288267
# Year      -0.008135
# Pts Won    0.995153
# Pts Max    0.521335
# Share      1.000000
# W          0.122718
# L         -0.121866
# W/L%       0.126559
# GB        -0.101014
# PS/G       0.045206
# PA/G      -0.039617
# SRS        0.122782
# Name: Share, dtype: float64

# %%
stats.corr()["Share"].plot.bar()
# Out:
# <AxesSubplot:>
